# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/MyDrive/Information code')
from function import *
import lxml
import time
import sys
import json
import requests
from textblob import TextBlob
from collections import Counter
import datetime
import nltk
import csv
import re
import csv
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#2017
videoId_all = ['EnLhcawaE5M','j1Dr53v3WCo','JxUPetG3JMI','Ii607X1YDs8','jqgIiyxXbWI','j1Dr53v3WCo']
getComment(videoId_all,'Garmin2017.txt',2017)
# Out:
# 2017-01-01
# 2017-02-01
# 2017-03-01
# 2017-04-01
# 2017-05-01
# 2017-06-01
# 2017-07-01
# 2017-08-01
# 2017-09-01
# 2017-10-01
# 2017-11-01
# 2017-12-01

# %%
positive_words,negative_words,text=read_text('Garmin2017.txt')
ctext = nlp(text)
cltext = lemmatize(ctext)
result = []
result.append(positive_analysis(positive_words,cltext))
result
# Out:
# hi all hope you enjoy this look at whats inside the boxes as noted these are final production units
# hi all hope you enjoy this look at whats inside the boxes as noted these are final production units from
# ['hi', 'hope', 'enjoy', 'look', 'whats', 'inside', 'boxes', 'noted', 'final', 'production', 'units', 'hardware', 'standpoint', 'however', 'currently', 'running', 'beta', 'firmware', 'get', 'final', 'firmware', 'ill', 'aim', 'weeks', 'later', 'indepth', 'review', 'likely', 'putting', 'midmarch', 'plenty', 'goodness', 'comelove', 'videos', 'theyre', 'informative', 'excited', 'fenix', 'sgreat', 'video', 'totally', 'loved', 'great', 'work', 'many', 'thanksthanks', 'dcr', 'looking', 'forward', 'hearing', 'features', 'benifits', 'x', 'triathletes', 'comparison', 'xt', 'time', 'upgrade', 'firstever', 'fenix', 'already', 'preordered', 'sapphire', 'cant', 'waitiv', 'waiting', 'video', 'pleased', 'see', 'even', 'though', 'wont', 'buying', 'one', 'quite', 'already', 'fenix', 'look', 'fantasticthat', 'b', 'roll', 'great', 'vidthanx', 'dc', 'rainmaker', 'unboxing', 'fenix', 'x', 'saphirethanks', 'video', 'would', 'love', 'see', 'detailed', 'comparison', 'x', 'hr', 'one', 'images', 'x']
# hi hope enjoy look whats inside box noted final production unit hardware standpoint however currentl
# Total positive words: 759, Total words: 30424, Positive ratio: 2.49%
# [0.02494740993952143]

# %%
#2018
videoId_all2 = ['uW26ZhNeFz8','WXpKmjlezxY','7GtYtVN9aDs','BIjdpjrx7oU','ItHssegAmfY','kjlwAIWQGHo']
getComment(videoId_all2,'Garmin2018.txt',2018)
# Out:
# 2018-01-01
# 2018-02-01
# 2018-03-01
# 2018-04-01
# 2018-05-01
# 2018-06-01
# 2018-07-01
# 2018-08-01
# 2018-09-01
# 2018-10-01
# 2018-11-01
# 2018-12-01

# %%
positive_words,negative_words,text2=read_text('Garmin2018.txt')
ctext2 = nlp(text2)
cltext2 = lemmatize(ctext2)
result.append(positive_analysis(positive_words,cltext2))
result
# Out:
# fantastic walkthru thanks so muchexcellent handson review on the features and how to operate the gar
# fantastic walkthru thanks so muchexcellent handson review on the features and how to operate the garmin forerunner nice one mate
# ['fantastic', 'walkthru', 'thanks', 'muchexcellent', 'handson', 'review', 'features', 'operate', 'garmin', 'forerunner', 'nice', 'one', 'mate', 'wonderful', 'walk', 'thru', 'info', 'straight', 'pointhi', 'thanks', 'detailed', 'review', 'ive', 'running', 'years', 'finally', 'looking', 'get', 'watch', 'track', 'runs', 'instead', 'phone', 'looks', 'like', 'right', 'one', 'mejust', 'seen', 'video', 'today', 'reason', 'ordered', 'one', 'refurbished', 'year', 'warranty', 'video', 'informative', 'sure', 'get', 'started', 'time', 'im', 'cyclists', 'garmin', 'edge', 'explorer', 'doesnt', 'things', 'thanksgarmin', 'connect', 'brillant', 'connects', 'quickly', 'helps', 'alotcan', 'add', 'kayaking', 'activity', 'forerunner', 'hey', 'mate', 'control', 'logging', 'interval', 'heart', 'ratehello', 'im', 'hard', 'time', 'finding', 'comes', 'need', 'go', 'far', 'charger', 'wire', 'cradled', 'im', 'scouring', 'amazon', 'like', 'wire', 'bundle', 'hey', 'really', 'sell', 'without', 'items']
# fantastic walkthru thanks muchexcellent handson review feature operate garmin forerunner nice one ma
# Total positive words: 474, Total words: 16638, Positive ratio: 2.85%
# [0.02494740993952143, 0.0284890010818608]

# %%
#2019
videoId_all3 = ['AX1xUy0K6PU','ezglERAKCzA','CbeX_ruKt3k','F4BIBCZemiY','I0JfnURhqYc','S_QR7sZhcMw']
getComment(videoId_all3,'Garmin2019.txt',2019)
# Out:
# 2019-01-01
# 2019-02-01
# 2019-03-01
# 2019-04-01
# 2019-05-01
# 2019-06-01
# 2019-07-01
# 2019-08-01
# 2019-09-01
# 2019-10-01
# 2019-11-01
# 2019-12-01

# %%
positive_words,negative_words,text3=read_text('Garmin2019.txt')
ctext3 = nlp(text3)
cltext3 = lemmatize(ctext3)
result.append(positive_analysis(positive_words,cltext3))
result
# Out:
#  garmin marq athlete samsung galaxy watch active coros vertix gps adventure watch suunto  garmin for
# garmin marq athlete samsung galaxy watch active coros vertix gps adventure watch suunto garmin forerunner garmin forerunner music garmin forerunner
# ['garmin', 'marq', 'athlete', 'samsung', 'galaxy', 'watch', 'active', 'coros', 'vertix', 'gps', 'adventure', 'watch', 'suunto', 'garmin', 'forerunner', 'garmin', 'forerunner', 'music', 'garmin', 'forerunner', 'fitbit', 'versa', 'coros', 'apex', 'pro', 'polar', 'ignite', 'apple', 'watch', 'series', 'samsung', 'galaxy', 'watch', 'active', 'garmin', 'fenix', 'garmin', 'fenix', 'x', 'pro', 'solar', 'garmin', 'vvoactive', 'garmin', 'venu', 'garmin', 'swim', 'garmin', 'marq', 'limitededition', 'signature', 'setthese', 'collaborative', 'reviews', 'appreciatedi', 'watched', 'review', 'love', 'videos', 'recently', 'started', 'reading', 'rainmaker', 'made', 'mind', 'hrm', 'band', 'watch', 'considering', 'opinionsi', 'love', 'seriously', 'take', 'reviews', 'deeply', 'thoroughly', 'analysisgreat', 'review', 'overview', 'watches', 'perfect', 'watch', 'still', 'improves', 'thank', 'thatsubscribed', 'forever', 'ago', 'des', 'happy', 'see', 'growing', 'well', 'great', 'collabtwo', 'favorites', 'great', 'video', 'alwaysexcellent', 'stuff']
# garmin marq athlete samsung galaxy watch active coros vertix gps adventure watch suunto garmin forer
# Total positive words: 1881, Total words: 71779, Positive ratio: 2.62%
# [0.02494740993952143, 0.0284890010818608, 0.02620543613034453]

# %%
#2020
videoId_all4 = ['YmAjJijnP-s','hVDicb_IXGI','AZiKJTOo2JY','jHTEJjBGrGI','_nx_JRh7_7s','Uvg81kgWibU']
getComment(videoId_all4,'Garmin2020.txt',2020)
# Out:
# 2020-01-01
# 2020-02-01
# 2020-03-01
# 2020-04-01
# 2020-05-01
# 2020-06-01
# 2020-07-01
# 2020-08-01
# 2020-09-01
# 2020-10-01
# 2020-11-01
# 2020-12-01

# %%
positive_words,negative_words,text4=read_text('Garmin2020.txt')
ctext4 = nlp(text4)
cltext4 = lemmatize(ctext4)
result.append(positive_analysis(positive_words,cltext4))
result
# Out:
# it looks very appealing to me i must say like that youre so indepth and thorough with everything gre
# it looks very appealing to me i must say like that youre so indepth and thorough with everything great jobgreat
# ['looks', 'appealing', 'must', 'say', 'like', 'youre', 'indepth', 'thorough', 'everything', 'great', 'jobgreat', 'video', 'alwaysgreat', 'review', 'brother', 'music', 'storagethank', 'review', 'watch', 'compatible', 'garmin', 'coachactually', 'fenix', 'already', 'market', 'plans', 'make', 'review', 'quite', 'interesting', 'compare', 'fenix', 'thanks', 'review', 'actually', 'got', 'fenix', 'go', 'garmin', 'fenix', 'thinkgarmin', 'fenix', 'coming', 'future', 'first', 'time', 'hear', 'insights', 'time', 'market', 'price', 'ranges', 'fenix', 'hr', 'replaced', 'apple', 'watch', 'beast', 'hope', 'delivers', 'updates', 'made', 'apple', 'watch', 'obsolete', 'answer', 'calls', 'watchthe', 'garmin', 'pay', 'app', 'doesnt', 'work', 'uk', 'doesnt', 'even', 'take', 'mastercardwhat', 'think', 'garmins', 'power', 'screen', 'technologythanks', 'review', 'always', 'good', 'see', 'reviews', 'smaller', 'sized', 'watches', 'since', 'thin', 'wrist', 'helps', 'gauge', 'may', 'look', 'meone', 'best']
# look appealing must say like youre indepth thorough everything great jobgreat video alwaysgreat revi
# Total positive words: 2496, Total words: 87518, Positive ratio: 2.85%
# [0.02494740993952143,
#  0.0284890010818608,
#  0.02620543613034453,
#  0.028519847345688888]

# %%
#2021
videoId_all5 = ['dWpBH8l6kPU','EemFOZJzBXk','DmaX27oqYnM','x3wRlCEnVi8','nUgu804j-cI','N0S6yjgsLIc']
getComment(videoId_all5,'Garmin2021.txt',2021)
# Out:
# 2021-01-01
# 2021-02-01
# 2021-03-01
# 2021-04-01
# 2021-05-01
# 2021-06-01
# 2021-07-01
# 2021-08-01
# 2021-09-01
# 2021-10-01
# 2021-11-01
# 2021-12-01

# %%
positive_words,negative_words,text5=read_text('Garmin2021.txt')
ctext5 = nlp(text5)
cltext5 = lemmatize(ctext5)
result.append(positive_analysis(positive_words,cltext5))
result
# Out:
# i wasnt going to get one but the gummy bear container sold it to me might even get one for my wifeha
# i wasnt going to get one but the gummy bear container sold it to me might even get one for
# ['wasnt', 'going', 'get', 'one', 'gummy', 'bear', 'container', 'sold', 'might', 'even', 'get', 'one', 'wifehad', 'bring', 'jacket', 'one', 'pointwith', 'gen', 'two', 'garmin', 'fixed', 'issue', 'gen', 'one', 'brightness', 'display', 'outdoors', 'issue', 'must', 'say', 'new', 'display', 'looks', 'amazing', 'maybe', 'time', 'need', 'upgrade', 'gen', 'one', 'itll', 'gen', 'three', 'happy', 'every', 'minute', 'wrist', 'caulk', 'buying', 'tool', 'use', 'multiple', 'times', 'hour', 'every', 'day', 'year', 'price', 'per', 'use', 'bargainin', 'review', 'marq', 'considered', 'similar', 'epix', 'actually', 'display', 'smaller', 'epix', 'big', 'difference', 'watchesit', 'looks', 'really', 'really', 'good', 'far', 'best', 'looking', 'sportswatch', 'farits', 'good', 'morning', 'mr', 'dc', 'new', 'videoawesome', 'got', 'yt', 'hoping', 'received', 'reviewed', 'one', 'incredibly', 'good', 'looking', 'watch', 'around', 'look']
# wasnt going get one gummy bear container sold might even get one wifehad bring jacket one pointwith
# Total positive words: 1616, Total words: 62844, Positive ratio: 2.57%
# [0.02494740993952143,
#  0.0284890010818608,
#  0.02620543613034453,
#  0.028519847345688888,
#  0.025714467570492013]

# %%
#2022
videoId_all6 = ['6LHgirNXEMI','_GNuNgofh48','exxmZq5aAJc','KgWERGs7v4E','__6ht7NRxhk','Nq6jgcdMfdA']
getComment(videoId_all6,'Garmin2022.txt',2022)
# Out:
# 2022-01-01
# can't get further news

# %%
positive_words,negative_words,text6=read_text('Garmin2022.txt')
ctext6 = nlp(text6)
cltext6 = lemmatize(ctext6)
result.append(positive_analysis(positive_words,cltext6))
result
# Out:
# i deserve the watch as i decided exactly one year ago to stop being a lazy slob and commit to walkin
# i deserve the watch as i decided exactly one year ago to stop being a lazy slob and commit to
# ['deserve', 'watch', 'decided', 'exactly', 'one', 'year', 'ago', 'stop', 'lazy', 'slob', 'commit', 'walking', 'miles', 'per', 'day', 'year', 'later', 'idea', 'mapping', 'features', 'help', 'find', 'way', 'home', 'deserve', 'new', 'garmin', 'fr', 'coach', 'local', 'running', 'club', 'also', 'scout', 'leader', 'map', 'feature', 'helpful', 'especially', 'works', 'well', 'foresty', 'foresty', 'whatever', 'bits', 'metrics', 'better', 'coach', 'able', 'teach', 'athletes', 'help', 'improve', 'solar', 'charging', 'extremely', 'helpful', 'scout', 'camp', 'also', 'interested', 'new', 'hrv', 'dad', 'massive', 'heart', 'attack', 'last', 'year', 'think', 'might', 'hereditary', 'great', 'video', 'guys', 'informativenew', 'garminyour', 'video', 'shared', 'lot', 'stuff', 'find', 'helpful', 'thank', 'youi', 'deserve', 'watch', 'ive', 'put', 'major', 'focus', 'physical', 'health', 'taking', 'number', 'sports', 'tracking', 'started', 'riding', 'running']
# deserve watch decided exactly one year ago stop lazy slob commit walking mile per day year later ide
# Total positive words: 3450, Total words: 118990, Positive ratio: 2.90%
# [0.02494740993952143,
#  0.0284890010818608,
#  0.02620543613034453,
#  0.028519847345688888,
#  0.025714467570492013,
#  0.02899403311202622]

# %%
#2023
videoId_all7 = ['sAz9WQOkKb0','K-ubFVhef6Q','vEdTx9PC27Q','vOUKBRquC-k','iNV9HLRrQLM','xIJgwH6SPyY']
getComment(videoId_all7,'Garmin2023.txt',2023)
# Out:
# 2023-01-01
# can't get further news

# %%
positive_words,negative_words,text7=read_text('Garmin2023.txt')
ctext7 = nlp(text7)
cltext7 = lemmatize(ctext7)
result.append(positive_analysis(positive_words,cltext7))
result
# Out:
# old  very experienced runner first marathon in  here i currently run with the forerunner   i am thin
# old very experienced runner first marathon in here i currently run with the forerunner i am thinking about upgrading to
# ['old', 'experienced', 'runner', 'first', 'marathon', 'currently', 'run', 'forerunner', 'thinking', 'upgrading', 'forerunner', 'mainly', 'better', 'battery', 'lifestarted', 'running', 'months', 'turning', 'turned', 'month', 'couldnt', 'run', 'mile', 'started', 'run', 'days', 'week', 'k', 'days', 'k', 'times', 'month', 'hard', 'time', 'getting', 'miles', 'start', 'following', 'lot', 'advice', 'channel', 'past', 'year', 'thanks', 'keep', 'great', 'workim', 'addicted', 'types', 'videos', 'spend', 'hours', 'hours', 'researching', 'buy', 'sometimes', 'dont', 'even', 'buy', 'wanted', 'forerunner', 'checking', 'prices', 'constantly', 'last', 'months', 'seems', 'like', 'amazing', 'value', 'budget', 'picked', 'running', 'hobby', 'last', 'year', 'started', 'kms', 'without', 'training', 'completed', 'half', 'marathons', 'recently', 'part', 'runners', 'group', 'training', 'program', 'watch', 'running', 'videos', 'youtube', 'feel', 'inspired', 'push', 'signed', 'first', 'full', 'marathon']
# old experienced runner first marathon currently run forerunner thinking upgrading forerunner mainly
# Total positive words: 6418, Total words: 176185, Positive ratio: 3.64%
# [0.02494740993952143,
#  0.0284890010818608,
#  0.02620543613034453,
#  0.028519847345688888,
#  0.025714467570492013,
#  0.02899403311202622,
#  0.036427618696256776]

# %%
years = [2017, 2018, 2019, 2020, 2021, 2022, 2023]
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.plot(years, result, marker='o')
plt.title('Garmin Sentiment Ratings from 2017 to 2023')
plt.xlabel('Year')
plt.ylabel('Sentiment Rating (%)')

plt.grid(True)
plt.show()

# %%
negresults = []
negresults.append(negative_analysis(negative_words,cltext))

negresults.append(negative_analysis(negative_words,cltext2))
negresults.append(negative_analysis(negative_words,cltext3))
negresults.append(negative_analysis(negative_words,cltext4))
negresults.append(negative_analysis(negative_words,cltext5))
negresults.append(negative_analysis(negative_words,cltext6))
negresults.append(negative_analysis(negative_words,cltext7))
negresults
# Out:
# Total nagetive words: 656, Total words: 30424, Nagetive ratio: 2.16%
# Total nagetive words: 320, Total words: 16638, Nagetive ratio: 1.92%
# Total nagetive words: 1432, Total words: 71779, Nagetive ratio: 2.00%
# Total nagetive words: 1779, Total words: 87518, Nagetive ratio: 2.03%
# Total nagetive words: 1253, Total words: 62844, Nagetive ratio: 1.99%
# Total nagetive words: 2349, Total words: 118990, Nagetive ratio: 1.97%
# Total nagetive words: 2827, Total words: 176185, Nagetive ratio: 1.60%
# [0.021561924796213515,
#  0.01923308089914653,
#  0.0199501246882793,
#  0.020327246966338353,
#  0.019938259817961938,
#  0.01974115471888394,
#  0.016045633850781848]

# %%
plt.figure(figsize=(10, 5))
result_percent = [x * 100 for x in result]
negresult_percent = [y * 100 for y in negresults]
plt.plot(years, result_percent, marker='o', label='Positive Ratings', color='blue')

plt.plot(years, negresult_percent, marker='x', label='Negative Ratings', color='red')

plt.legend()
for year, value in zip(years, result_percent):
    plt.text(year, value, f'{value:.1f}%', fontsize=9, ha='center', va='bottom')
for year, value in zip(years, negresult_percent):
    plt.text(year, value, f'{value:.1f}%', fontsize=9, ha='center', va='bottom')

plt.title('Garmin sentiment Ratings from 2017 to 2023')
plt.xlabel('Year')
plt.ylabel('Sentiment Rating (%)')
plt.grid(True)
plt.show()

# %%
all_text = cltext+' '+cltext2+' '+cltext3+' '+cltext4+' '+cltext5+' '+cltext6+' '+cltext7
positive_freq = positive(positive_words,all_text)
from wordcloud import WordCloud
import matplotlib.pyplot as plt



wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(positive_freq)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
#       Word  Frequency
# 0      run       1926
# 1     like        842
# 2    thank        815
# 3    great        810
# 4      new        735
# 5  running        694
# 6     love        669
# 7     feat        511
# 8     work        447
# 9     good        412
# Total positive words: 17094, Total words: 564384, Positive ratio: 3.03%
