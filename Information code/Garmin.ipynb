# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/MyDrive/Information code')
from function import *
import lxml
import time
import sys
import json
import requests
from textblob import TextBlob
from collections import Counter
import datetime
import nltk
import csv
import re
import csv
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#2017
videoId_all = ['EnLhcawaE5M','j1Dr53v3WCo','JxUPetG3JMI','Ii607X1YDs8','jqgIiyxXbWI','j1Dr53v3WCo']
getComment(videoId_all,'Garmin2017.txt',2017)
# Out:
# 2017-01-01
# 2017-02-01
# 2017-03-01
# 2017-04-01
# 2017-05-01
# 2017-06-01
# 2017-07-01
# 2017-08-01
# 2017-09-01
# 2017-10-01
# 2017-11-01
# 2017-12-01

# %%
positive_words,negative_words,text=read_text('Garmin2017.txt')
ctext = nlp(text)
cltext = lemmatize(ctext)
result = []
result.append(positive_analysis(positive_words,cltext))
result
# Out:
# hi all hope you enjoy this look at whats inside the boxes as noted these are final production units from a hardware standpoint however they are currently running beta firmware  once i get final firmware ill aim for about  weeks later for an indepth review likely putting it midmarch plenty of goodness to comelove your videos theyre so informative so excited for the fenix siv been waiting for this video very pleased to see it even though i wont be buying one for quite a while because i already have the fenix  they look fantasticthanks dcr looking forward to hearing about the features and benifits of the x for triathletes in comparison to the xt time to upgrade from the this will be my firstever fenix already preordered sapphire  and cant waitthanks for the video would love to see a detailed comparison between the x and hr in one of the images the x looks slightly thinner than the hri think the sapphire is worth the money i owned a lot of mineral glass watches and they all had scratches
# ...

# %%
#2018
videoId_all2 = ['uW26ZhNeFz8','WXpKmjlezxY','7GtYtVN9aDs','BIjdpjrx7oU','ItHssegAmfY','kjlwAIWQGHo']
getComment(videoId_all2,'Garmin2018.txt',2018)
# Out:
# 2018-01-01
# 2018-02-01
# 2018-03-01
# 2018-04-01
# 2018-05-01
# 2018-06-01
# 2018-07-01
# 2018-08-01
# 2018-09-01
# 2018-10-01
# 2018-11-01
# 2018-12-01

# %%
positive_words,negative_words,text=read_text('Garmin2018.txt')
ctext2 = nlp(text2)
cltext2 = lemmatize(ctext2)
result.append(positive_analysis(positive_words,cltext2))
result
# Out:
# excellent handson review on the features and how to operate the garmin forerunner  nice one mate hi thanks for the detailed review ive been running for about  years and finally looking to get a watch to track my runs instead of my phone looks like this is the right one for mefantastic walkthru thanks so muchwonderful walk thru your info is straight and to the pointjust seen this video today reason ordered one that was refurbished  with  year warranty  your video is very informative for sure now can get started in no time im a cyclists have garmin edge explorer but doesnt do any other things thanksgarmin connect is brillant it connects very quickly it helps me alothey mate can you control logging interval of heart ratethankscan you add kayaking activity on the forerunner hello   im having a hard time finding out if it comes with all you need to go as far as charger wire and cradled  im scouring amazon and its like    and then   with wire bundle    do hey really sell this without all t
# ...

# %%
#2019
videoId_all3 = ['AX1xUy0K6PU','ezglERAKCzA','CbeX_ruKt3k','F4BIBCZemiY','I0JfnURhqYc','S_QR7sZhcMw']
getComment(videoId_all3,'Garmin2019.txt',2019)
# Out:
# 2019-01-01
# 2019-02-01
# 2019-03-01
# 2019-04-01
# 2019-05-01
# 2019-06-01
# 2019-07-01
# 2019-08-01
# 2019-09-01
# 2019-10-01
# 2019-11-01
# 2019-12-01

# %%
positive_words,negative_words,text=read_text('Garmin2019.txt')
ctext3 = nlp(text3)
cltext3 = lemmatize(ctext3)
result.append(positive_analysis(positive_words,cltext3))
result
# Out:
#  garmin marq athlete samsung galaxy watch active coros vertix gps adventure watch suunto  garmin forerunner  garmin forerunner  music garmin forerunner  fitbit versa  coros apex pro polar ignite apple watch series  samsung galaxy watch active garmin fenix  garmin fenix x pro solar garmin vvoactive  garmin venu garmin swim  garmin marq limitededition signature setthese collaborative reviews are so appreciatedgreat review and overview of all watches for me the  was the perfect watch in  and it still improves thank you for thatsubscribed to you forever ago des happy to see you growing and doing so well    great collabtwo of my favorites  great video as alwaysi just watched this review i love your videos and i recently started reading rainmaker i made my mind on hrm band and watch considering both of your opinionsi just love how seriously you take the reviews how deeply and thoroughly is your analysisif you like this video youll love our new podcast weve extended our yearend chats to a r
# ...

# %%
#2020
videoId_all4 = ['YmAjJijnP-s','hVDicb_IXGI','AZiKJTOo2JY','jHTEJjBGrGI','_nx_JRh7_7s','Uvg81kgWibU']
getComment(videoId_all4,'Garmin2020.txt',2020)
# Out:
# 2020-01-01
# 2020-02-01
# 2020-03-01
# 2020-04-01
# 2020-05-01
# 2020-06-01
# 2020-07-01
# 2020-08-01
# 2020-09-01
# 2020-10-01
# 2020-11-01
# 2020-12-01

# %%
positive_words,negative_words,text=read_text('Garmin2020.txt')
ctext4 = nlp(text4)
cltext4 = lemmatize(ctext4)
result.append(positive_analysis(positive_words,cltext4))
result
# Out:
# it looks very appealing to me i must say like that youre so indepth and thorough with everything great jobgreat review brother do it have music storagegreat  video as alwaysthank you for the review  is the watch compatible with garmin coachs  or fenix hr actually fenix  is already out there in the market any plans to make a review on it as its quite interesting to compare them with fenix thanks for the review actually i have got fenix  how does it go against garmin fenix s what do you thinkreplaced my apple watch  for this beast i hope it delivers all the updates made the apple watch obsolete in garmin fenix  in the coming future its the first time i hear it any insights on the time when on the market and price rangecan you answer calls on this watchthe garmin pay app doesnt work in the uk doesnt even take mastercardwhat do you think to garmins power screen technologythanks for the review its always good for me to see these reviews on the smaller sized watches since i have a thin wri
# ...

# %%
#2021
videoId_all5 = ['dWpBH8l6kPU','EemFOZJzBXk','DmaX27oqYnM','x3wRlCEnVi8','nUgu804j-cI','N0S6yjgsLIc']
getComment(videoId_all5,'Garmin2021.txt',2021)
# Out:
# 2021-01-01
# 2021-02-01
# 2021-03-01
# 2021-04-01
# 2021-05-01
# 2021-06-01
# 2021-07-01
# 2021-08-01
# 2021-09-01
# 2021-10-01
# 2021-11-01
# 2021-12-01

# %%
positive_words,negative_words,text=read_text('Garmin2021.txt')
ctext5 = nlp(text5)
cltext5 = lemmatize(ctext5)
result.append(positive_analysis(positive_words,cltext5))
result
# Out:
# i wasnt going to get one but the gummy bear container sold it to me might even get one for my wifehad to bring out the jacket for this one on pointwith gen two garmin fixed the only issue that gen one had  the brightness of the display outdoors there was no issue i must say the new display looks amazing and maybe by the time i need to upgrade my gen one itll be gen three  but happy with it every minute it is on  my wrist caulk it up to buying a tool that you use multiple times an hour every day of the year and the price per use is a bargainin the review the marq  is considered similar to epix  but actually it has a display of  which is smaller than the  of the epix  that is a big difference between the watchesits a good morning when mr dc has a new videoim owning a marq commander gen  and im wearing it nonstop for three years now for me it is the best watch i ever had its also the smallest of the marq collection and the size fits best the other models are too chunky got it second han
# ...

# %%
#2022
videoId_all6 = ['6LHgirNXEMI','_GNuNgofh48','exxmZq5aAJc','KgWERGs7v4E','__6ht7NRxhk','Nq6jgcdMfdA']
getComment(videoId_all6,'Garmin2022.txt',2022)
# Out:
# 2022-01-01
# can't get further news

# %%
positive_words,negative_words,text6=read_text('Garmin2022.txt')
ctext6 = nlp(text6)
cltext6 = lemmatize(ctext6)
result.append(positive_analysis(positive_words,cltext6))
result
# Out:
# i deserve the watch as i decided exactly one year ago to stop being a lazy slob and commit to walking  miles per day its now  year later and i have no idea where i am so having the mapping features will help me find my way home i deserve the new garmin fr because i am a coach with my local running club and also a scout leader the map feature will be very helpful especially if it works well in the foresty foresty or whatever is up there bits the more metrics i have for myself the better coach i can be as i will be able to teach my athletes about them and help them improve the solar charging will be extremely helpful on scout camp too i am also interested in the new hrv my dad had a massive heart attack last year and they think it might be hereditary great video guys very informativenew to garminyour video shared a lot of stuff which i will find helpful thank youi deserve this watch because ive put major focus into my physical health by taking up a number of sports that i have no track
# ...

# %%
#2023
videoId_all7 = ['sAz9WQOkKb0','K-ubFVhef6Q','vEdTx9PC27Q','vOUKBRquC-k','iNV9HLRrQLM','xIJgwH6SPyY']
getComment(videoId_all7,'Garmin2023.txt',2023)
# Out:
# 2023-01-01
# can't get further news

# %%
positive_words,negative_words,text7=read_text('Garmin2023.txt')
ctext7 = nlp(text7)
cltext7 = lemmatize(ctext7)
result.append(positive_analysis(positive_words,cltext7))
result
# Out:
# old  very experienced runner first marathon in  here i currently run with the forerunner   i am thinking about upgrading to the forerunner  mainly for the better battery lifestarted running a few months after turning  just turned  this month couldnt run a mile when i started now i run  days a week k most days and k  times a month had a hard time getting my miles up until i start following a lot of the advice from your channel over the past year thanks keep up the great workim addicted to these types of videos i spend hours and hours researching what i should buy and sometimes dont even buy what i wanted but the forerunner  has me checking prices constantly for the last  months seems like an amazing value just out of my budget so i have picked up running as a hobby last year i started with kms without any training  now i completed my  half marathons recently i am not part of any runners group or any training program i just watch running videos on youtube  feel inspired to push myself 
# ...

# %%
years = [2017, 2018, 2019, 2020, 2021, 2022, 2023]
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.plot(years, result, marker='o')
plt.title('Garmin Sentiment Ratings from 2017 to 2023')
plt.xlabel('Year')
plt.ylabel('Sentiment Rating (%)')

plt.grid(True)
plt.show()

# %%
negresults = []
negresults.append(negative_analysis(negative_words,cltext))

negresults.append(negative_analysis(negative_words,cltext2))
negresults.append(negative_analysis(negative_words,cltext3))
negresults.append(negative_analysis(negative_words,cltext4))
negresults.append(negative_analysis(negative_words,cltext5))
negresults.append(negative_analysis(negative_words,cltext6))
negresults.append(negative_analysis(negative_words,cltext7))
negresults
# Out:
# Negative words frequency: {'ache': 4, 'ached': 3, 'aching': 6, 'ail': 24, 'ailing': 3, 'alarm': 4, 'anger': 1, 'annoy': 1, 'annoying': 1, 'ax': 2, 'bad': 4, 'beg': 2, 'begging': 1, 'belie': 3, 'bother': 1, 'brat': 6, 'bs': 9, 'bug': 2, 'buggy': 1, 'bulky': 1, 'bum': 1, 'bunk': 1, 'burn': 3, 'burned': 1, 'cold': 1, 'complain': 1, 'complaint': 1, 'complicated': 2, 'conflict': 1, 'conflicted': 1, 'confuse': 1, 'confused': 1, 'cons': 6, 'crack': 2, 'cracked': 2, 'crap': 1, 'crazy': 1, 'damage': 2, 'damn': 2, 'defect': 1, 'defective': 1, 'demon': 1, 'dent': 1, 'din': 16, 'ding': 12, 'dire': 6, 'disapointing': 2, 'disappoint': 1, 'disaster': 2, 'dishonest': 1, 'dishonesty': 1, 'distract': 1, 'distracting': 1, 'dizzy': 1, 'doubt': 1, 'dud': 4, 'dying': 1, 'err': 2, 'error': 1, 'errors': 1, 'exclusion': 1, 'excuse': 1, 'exhaust': 1, 'exhausted': 1, 'expensive': 2, 'fail': 2, 'failing': 1, 'fall': 1, 'fault': 1, 'freeze': 2, 'frustrating': 1, 'fuzzy': 1, 'grief': 1, 'hang': 8, 'hard': 11, 'ha
# ...

# %%
plt.figure(figsize=(10, 5))
result_percent = [x * 100 for x in result]
negresult_percent = [y * 100 for y in negresults]
plt.plot(years, result_percent, marker='o', label='Positive Ratings', color='blue')

plt.plot(years, negresult_percent, marker='x', label='Negative Ratings', color='red')

plt.legend()
for year, value in zip(years, result_percent):
    plt.text(year, value, f'{value:.1f}%', fontsize=9, ha='center', va='bottom')
for year, value in zip(years, negresult_percent):
    plt.text(year, value, f'{value:.1f}%', fontsize=9, ha='center', va='bottom')

plt.title('Garmin sentiment Ratings from 2017 to 2023')
plt.xlabel('Year')
plt.ylabel('Sentiment Rating (%)')
plt.grid(True)
plt.show()

# %%
ratios = [pos / neg for pos, neg in zip(result, negresults)]


plt.figure(figsize=(10, 5))
plt.plot(years, ratios, marker='o', linestyle='-', color='blue', label='Positive/Negative Ratio')
for (x, y) in zip(years, ratios):
    plt.text(x, y, f'{y:.2f}', color='black', fontsize=10, ha='center', va='bottom')
plt.legend()
plt.title('Ratio of Positive to Negative Ratings by Year')
plt.xlabel('Year')
plt.ylabel('Positive/Negative Ratio')
plt.grid(True)
plt.show()

# %%
all_text = cltext+' '+cltext2+' '+cltext3+' '+cltext4+' '+cltext5+' '+cltext6+' '+cltext7
positive_freq = positive(positive_words,all_text)
from wordcloud import WordCloud
import matplotlib.pyplot as plt



wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(positive_freq)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
#       Word  Frequency
# 0      run       1919
# 1     like        825
# 2    thank        786
# 3    great        782
# 4      new        732
# 5  running        689
# 6     love        659
# 7     feat        497
# 8     work        435
# 9     good        400
# Total positive words: 16727, Total words: 551343, Positive ratio: 3.03%
